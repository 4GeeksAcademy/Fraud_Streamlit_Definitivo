# %% [markdown]
# # Explore here

# %%
import joblib
import streamlit as st
import os
import gzip
import pandas as pd
from sklearn.ensemble import RandomForestClassifier

# Usamos una ruta relativa para acceder al directorio de 'models'
RUTA_MODELO = "modelo_RandomForest_optimizado.pkl.gz"

# Función para cargar el modelo comprimido
def cargar_modelo_comprimido(ruta):
    """Carga el modelo comprimido con gzip."""
    if not os.path.exists(ruta):
        raise FileNotFoundError(f"El archivo {ruta} no existe. Verifica que está en la carpeta correcta.")
    
    with gzip.open(ruta, "rb") as f:
        modelo = joblib.load(f)
    print("✅ Modelo cargado exitosamente.")
    return modelo

# Cargar el modelo
try:
    model = cargar_modelo_comprimido(RUTA_MODELO)
except Exception as e:
    st.error(f"Error al cargar el modelo: {str(e)}")
    st.stop()

# Verificar si el modelo es correcto
if not isinstance(model, RandomForestClassifier):
    st.error("El archivo cargado no es un modelo RandomForest.")
    st.stop()

# Diccionario de clases
class_dict = {
    "0": "No Fraude",
    "1": "Fraude",
}

# Título de la aplicación
st.title("MODELO MACHINE LEARNING PARA LA PREDICCIÓN DE FRAUDE FINANCIERO")

# Menú de navegación
menu = st.sidebar.selectbox("Selecciona una opción", ["Predicción de Fraude", "Reseña sobre Fraudes Financieros"])

if menu == "Predicción de Fraude":
    st.header("Predicción de Fraude en Transacciones Bancarias")

    with st.form("Formulario de Datos"):
        st.subheader("Por favor, complete la siguiente información")
        
        income = st.number_input("Ingresos", min_value=0.0, max_value=1000000.0, step=1000.0)
        name_email_similarity = st.slider("Similitud entre Nombre y Email", min_value=0.0, max_value=1.0, step=0.01)
        prev_address_months_count = st.number_input("Meses en la Dirección Anterior", min_value=0, max_value=240, step=1)
        current_address_months_count = st.number_input("Meses en la Dirección Actual", min_value=0, max_value=240, step=1)
        customer_age = st.number_input("Edad del Cliente", min_value=18, max_value=100, step=1)
        intended_balcon_amount = st.number_input("Monto del Saldo Intencionado", min_value=0.0, max_value=1000000.0, step=1000.0)
        velocity_6h = st.number_input("Velocidad de Transacción en 6 Horas", min_value=0.0, max_value=1000.0, step=1.0)
        velocity_24h = st.number_input("Velocidad de Transacción en 24 Horas", min_value=0.0, max_value=1000.0, step=1.0)
        bank_branch_count_8w = st.number_input("Número de Sucursales Bancarias en 8 Semanas", min_value=0, max_value=20, step=1)
        date_of_birth_distinct_emails_4w = st.number_input("Correos Electrónicos Distintos en 4 Semanas", min_value=0, max_value=10, step=1)
        credit_risk_score = st.number_input("Puntuación de Riesgo Crediticio", min_value=0, max_value=1000, step=1)
        email_is_free = st.selectbox("Email es Gratuito", [0, 1])
        phone_home_valid = st.selectbox("Teléfono de Casa Válido", [0, 1])
        phone_mobile_valid = st.selectbox("Teléfono Móvil Válido", [0, 1])
        has_other_cards = st.selectbox("Tiene Otras Tarjetas", [0, 1])
        proposed_credit_limit = st.number_input("Límite de Crédito Propuesto", min_value=0.0, max_value=1000000.0, step=1000.0)
        foreign_request = st.selectbox("Solicitud Extranjera", [0, 1])
        keep_alive_session = st.number_input("Duración de la Sesión Activa", min_value=0.0, max_value=1440.0, step=1.0)
        device_distinct_emails_8w = st.number_input("Emails Distintos en 8 Semanas", min_value=0, max_value=10, step=1)
        month = st.slider("Mes", min_value=1, max_value=12, step=1)

        submit_button = st.form_submit_button(label="Predecir")

    if submit_button:
        # Lista de características en el mismo orden en que se entrenó el modelo
        columnas_correctas = [
            'income', 'name_email_similarity', 'prev_address_months_count',
            'current_address_months_count', 'customer_age', 'intended_balcon_amount',
            'velocity_6h', 'velocity_24h', 'bank_branch_count_8w',
            'date_of_birth_distinct_emails_4w', 'credit_risk_score', 'email_is_free',
            'phone_home_valid', 'phone_mobile_valid', 'has_other_cards',
            'proposed_credit_limit', 'foreign_request', 'keep_alive_session',
            'device_distinct_emails_8w', 'month'
        ]

        # Crear DataFrame asegurando que las columnas coincidan
        data_df = pd.DataFrame([[
            income, name_email_similarity, prev_address_months_count, current_address_months_count, customer_age,
            intended_balcon_amount, velocity_6h, velocity_24h, bank_branch_count_8w,
            date_of_birth_distinct_emails_4w, credit_risk_score, email_is_free, phone_home_valid,
            phone_mobile_valid, has_other_cards, proposed_credit_limit, foreign_request,
            keep_alive_session, device_distinct_emails_8w, month
        ]], columns=columnas_correctas)

        # Realizar la predicción
        prediction = str(model.predict(data_df)[0])
        pred_class = class_dict[prediction]
        st.write("🔮 **Predicción:**", pred_class)

elif menu == "Reseña sobre Fraudes Financieros":
    st.header("Reseña sobre Fraudes Financieros")
    st.write("Explicación sobre los fraudes financieros...")

# %%
"""import joblib
import streamlit as st
import os
import gzip
import pandas as pd
from sklearn.ensemble import RandomForestClassifier

# Usamos una ruta relativa para acceder al directorio de 'models'
RUTA_MODELO = "/workspaces/fraud_para_Render_Definitivo/models/modelo_RandomForest_optimizado.pkl.gz"

# Función para cargar el modelo comprimido
def cargar_modelo_comprimido(ruta):
    """Carga el modelo comprimido con gzip."""
    if not os.path.exists(ruta):
        raise FileNotFoundError(f"El archivo {ruta} no existe. Verifica que está en la carpeta models en Render.")

    with gzip.open(ruta, "rb") as f:
        modelo = joblib.load(f)
    print("✅ Modelo cargado exitosamente.")
    return modelo

# Cargar el modelo
try:
    model = cargar_modelo_comprimido(RUTA_MODELO)
except Exception as e:
    st.error(f"Error al cargar el modelo: {str(e)}")
    st.stop()

# Verificar si el modelo es correcto
if not isinstance(model, RandomForestClassifier):
    st.error("El archivo cargado no es un modelo RandomForest.")
    st.stop()

# Diccionario de clases
class_dict = {
    "0": "No Fraude",
    "1": "Fraude",
}

# Título de la aplicación
st.title("MODELO MACHINE LEARNING PARA LA PREDICCIÓN DE FRAUDE FINANCIERO")

# Menú de navegación
menu = st.sidebar.selectbox("Selecciona una opción", ["Predicción de Fraude", "Reseña sobre Fraudes Financieros"])

if menu == "Predicción de Fraude":
    st.header("Predicción de Fraude en Transacciones Bancarias")

    with st.form("Formulario de Datos"):
        st.subheader("Por favor, complete la siguiente información")
        
        income = st.number_input("Ingresos", min_value=0.0, max_value=1000000.0, step=1000.0)
        name_email_similarity = st.slider("Similitud entre Nombre y Email", min_value=0.0, max_value=1.0, step=0.01)
        prev_address_months_count = st.number_input("Meses en la Dirección Anterior", min_value=0, max_value=240, step=1)
        current_address_months_count = st.number_input("Meses en la Dirección Actual", min_value=0, max_value=240, step=1)
        customer_age = st.number_input("Edad del Cliente", min_value=18, max_value=100, step=1)
        intended_balcon_amount = st.number_input("Monto del Saldo Intencionado", min_value=0.0, max_value=1000000.0, step=1000.0)
        velocity_6h = st.number_input("Velocidad de Transacción en 6 Horas", min_value=0.0, max_value=1000.0, step=1.0)
        velocity_24h = st.number_input("Velocidad de Transacción en 24 Horas", min_value=0.0, max_value=1000.0, step=1.0)
        bank_branch_count_8w = st.number_input("Número de Sucursales Bancarias en 8 Semanas", min_value=0, max_value=20, step=1)
        date_of_birth_distinct_emails_4w = st.number_input("Correos Electrónicos Distintos en 4 Semanas", min_value=0, max_value=10, step=1)
        credit_risk_score = st.number_input("Puntuación de Riesgo Crediticio", min_value=0, max_value=1000, step=1)
        email_is_free = st.selectbox("Email es Gratuito", [0, 1])
        phone_home_valid = st.selectbox("Teléfono de Casa Válido", [0, 1])
        phone_mobile_valid = st.selectbox("Teléfono Móvil Válido", [0, 1])
        has_other_cards = st.selectbox("Tiene Otras Tarjetas", [0, 1])
        proposed_credit_limit = st.number_input("Límite de Crédito Propuesto", min_value=0.0, max_value=1000000.0, step=1000.0)
        foreign_request = st.selectbox("Solicitud Extranjera", [0, 1])
        keep_alive_session = st.number_input("Duración de la Sesión Activa", min_value=0.0, max_value=1440.0, step=1.0)
        device_distinct_emails_8w = st.number_input("Emails Distintos en 8 Semanas", min_value=0, max_value=10, step=1)
        month = st.slider("Mes", min_value=1, max_value=12, step=1)

        submit_button = st.form_submit_button(label="Predecir")

    if submit_button:
        # Lista de características en el mismo orden en que se entrenó el modelo
        columnas_correctas = [
            'income', 'name_email_similarity', 'prev_address_months_count',
            'current_address_months_count', 'customer_age', 'intended_balcon_amount',
            'velocity_6h', 'velocity_24h', 'bank_branch_count_8w',
            'date_of_birth_distinct_emails_4w', 'credit_risk_score', 'email_is_free',
            'phone_home_valid', 'phone_mobile_valid', 'has_other_cards',
            'proposed_credit_limit', 'foreign_request', 'keep_alive_session',
            'device_distinct_emails_8w', 'month'
        ]

        # Crear DataFrame asegurando que las columnas coincidan
        data_df = pd.DataFrame([[
            income, name_email_similarity, prev_address_months_count, current_address_months_count, customer_age,
            intended_balcon_amount, velocity_6h, velocity_24h, bank_branch_count_8w,
            date_of_birth_distinct_emails_4w, credit_risk_score, email_is_free, phone_home_valid,
            phone_mobile_valid, has_other_cards, proposed_credit_limit, foreign_request,
            keep_alive_session, device_distinct_emails_8w, month
        ]], columns=columnas_correctas)

        # Realizar la predicción
        prediction = str(model.predict(data_df)[0])
        pred_class = class_dict[prediction]
        st.write("🔮 **Predicción:**", pred_class)

elif menu == "Reseña sobre Fraudes Financieros":
    st.header("Reseña sobre Fraudes Financieros")
    st.write("Explicación sobre los fraudes financieros...")
"""
# Out:
# 2025-02-04 20:13:32.704 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.704 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.706 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.706 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.707 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.708 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.709 Session state does not function when running a script without `streamlit run`
# 2025-02-04 20:13:32.710 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.710 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.712 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.712 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.713 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.714 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.715 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.716 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.717 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.717 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.718 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.719 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.720 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.721 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.722 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.723 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.723 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.724 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.725 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.725 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.726 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.726 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.727 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.727 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.728 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.728 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.729 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.729 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.729 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.730 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.730 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.731 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.731 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.732 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.732 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.733 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.733 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.734 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.734 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.734 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.735 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.735 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.736 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.737 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.737 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.738 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.738 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.739 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.739 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.739 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.740 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.740 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.741 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.741 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.742 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.742 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.743 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.743 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.743 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.744 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.744 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.745 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.745 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.746 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.746 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.747 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.747 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.748 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.748 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.749 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.749 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.750 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.750 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.750 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.751 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.751 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.752 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.753 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.753 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.754 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.754 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.755 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.755 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.756 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.756 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.757 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.758 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.758 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.759 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.759 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.760 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.760 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.761 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.761 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.762 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.762 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.762 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.763 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.763 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.764 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.764 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.765 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.765 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.766 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.766 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.767 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.767 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.768 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.768 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.769 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.769 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.770 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.771 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.771 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.772 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.772 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.773 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.773 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.776 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.776 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.777 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.777 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.778 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.778 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.779 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.780 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.780 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.781 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.781 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.782 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.782 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.783 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-04 20:13:32.783 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ✅ Modelo cargado exitosamente.
